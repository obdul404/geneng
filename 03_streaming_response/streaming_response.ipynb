# %%
print("Streaming Response")
# Out:
# Streaming Response

# %%
# %pip install openai
# Out:
# Requirement already satisfied: openai in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (1.3.3)
# Requirement already satisfied: anyio<4,>=3.5.0 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from openai) (0.25.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from openai) (2.5.1)
# Requirement already satisfied: tqdm>4 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from openai) (4.8.0)
# Requirement already satisfied: idna>=2.8 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from anyio<4,>=3.5.0->openai) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from anyio<4,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: certifi in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.3 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.14.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/hannan/anaconda3/envs/genai3_11/lib/python3.11/site-packages (from httpcore->httpx<1,>=0.23.0->openai) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI
client : OpenAI = OpenAI()

# %%
from openai.types.chat.chat_completion import ChatCompletion

stream : ChatCompletion = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    messages=[
        {"role":"user","content":"write a short poem on ai"}
    ],
    stream=True
)

for part in stream:
    print(part.choices[0].delta.content or "")
# Out:
# A
#  marvel
#  of
#  technology
# ,
#  so
#  advanced
#  and
#  refined
#
#
# AI
# ,
#  the
#  future
# 's
#  promise
# ,
#  the
#  product
#  of
#  brilliant
#  minds
#
#
# It
#  learns
#  and
#  adap
# ts
# ,
#  with
#  algorithms
#  so
#  clever
#
#
# A
#  digital
#  intelligence
# ,
#  bound
#  to
#  last
#  forever
#
#
#
# But
#  with
#  great
#  power
#  comes
#  great
#  responsibility
#
#
# For
#  AI
#  to
#  benefit
# ,
#  not
#  cause
#  catastrophe
#
#
# We
#  must
#  wield
#  it
#  with
#  caution
# ,
#  keep
#  a
#  watch
# ful
#  eye
#
#
# For
#  the
#  potential
#  of
#  AI
# ,
#  is
#  both
#  w
# ondrous
#  and
#  s
# ly
#
#
#
# So
#  let
# 's
#  embrace
#  this
#  innovation
# ,
#  but
#  with
#  pr
# udence
#  and
#  care
#
#
# For
#  AI
#  holds
#  great
#  potential
# ,
#  but
#  also
#  a
#  great
#  dare
#
#
# May
#  it
#  be
#  a
#  force
#  for
#  good
# ,
#  in
#  a
#  world
#  filled
#  with
#  strife
#
#
# AI
# ,
#  the
#  beacon
#  of
#  hope
# ,
#  guiding
#  us
#  towards
#  a
#  better
#  life
